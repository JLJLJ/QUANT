# %%
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score  
from xgboost import XGBClassifier
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.wrappers import scikit_learn

import os
from tensorflow.keras import backend as K
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
K.set_session(tf.Session(config=config))
os.environ['CUDA_VISIBLE_DEVICES']='0'
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

import matplotlib as mpl
import seaborn as sns

import time
from functools import wraps
#import pysnooper


def fn_timer(function):
  @wraps(function)
  def function_timer(*args, **kwargs):
    t0 = time.time()
    result = function(*args, **kwargs)
    t1 = time.time()
    print ("Total time running %s: %s seconds" %
        (function.__name__, str(t1-t0)))
    return result
  return function_timer

# %matplotlib inline

dataset_train = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡).csv",header=0,index_col=0)
X_train=dataset_train.drop(columns =['target']).values
Y_train=dataset_train['target'].values

dataset_test = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡)线下测试集.csv",header=0,index_col=0)
X_test=dataset_test.drop(columns =['target']).values
Y_test=dataset_test['target'].values

# %%
li
# Out:
# [[0.01, 0.01, 0.01, 0.01, 64], [0.01, 0.01, 0.01, 0.01, 64]]

# %% [markdown]
# # 寻找最优参数

# %%
#li=[]
def run_model(layer1_kernel_l1,layer2_kernel_l1,batch_size):
    #global li
    class RocAucEvaluation(Callback):
        def __init__(self, validation_data=(), interval=1):
            super(Callback, self).__init__()
            self.interval = interval
            self.x_val,self.y_val,self.layer1_kernel_l1,self.layer2_kernel_l1,self.batch_size = validation_data
        def on_epoch_end(self, epoch, log={}):
            if epoch % self.interval == 0:
                #y_pred = self.model.predict(self.x_val, verbose=0)
                y_pred = self.model.predict(self.x_val, verbose=0)
                score = roc_auc_score(self.y_val, y_pred)
                s=str(score)+','+str(self.layer1_kernel_l1)+','+str(self.layer2_kernel_l1)+','+str(self.batch_size)
                #li.append([self.layer1_kernel_l1,self.layer1_kernel_l2,self.layer2_kernel_l1,self.layer2_kernel_l2,self.batch_size,score])
                with open('模型/dnn/一晚上.txt', "a") as f:
                    f.write(s+','+str(epoch)+'\n')
                if(score>0.8476):
                    model.save('模型/dnn/auc'+s+'.h5')
                    print('模型已保存:'+'模型/dnn/auc'+str(score)+'.h5')
                if(score<0.55):
                    raise 'AUC太低，别跑了'
                print('\n ROC_AUC - epoch:%d - score:%.6f \n' % (epoch+1, score))

    RocAuc = RocAucEvaluation(validation_data=(X_test, Y_test,
                                               layer1_kernel_l1,layer2_kernel_l1,batch_size),
                              interval=1)
    
    model = Sequential()
    model.add(Dense(units=300, activation='relu', input_dim=200#,
                    #kernel_regularizer=regularizers.l2(0.01),
                    #activity_regularizer=regularizers.l1(0.01) #效果挺好
                    #kernel_regularizer=regularizers.l1(layer1_kernel_l1)#,
                   # activity_regularizer=regularizers.l1(layer1_kernel_l2)

                   ))
    model.add(Dense(units=200,activation='relu',
                    kernel_regularizer=regularizers.l1(layer2_kernel_l1)#,
                    #activity_regularizer=regularizers.l1(layer2_kernel_l2)

                   ))
    #model.add(Dense(units=64,activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    #model.compile(loss='binary_crossentropy',optimizer='adam',metrics=[roc_auc_score])
    #model.fit(X_train,Y_train,epochs=500,batch_size=128)
    model.fit(X_train, Y_train, batch_size=batch_size, epochs=100, validation_data=(X_test, Y_test), callbacks=[RocAuc], verbose=2)
    return model
    #evaluate the model
    '''scores = model.evaluate(X_test,Y_test)
    print("\n%s:%.2f%%" % (model.metrics_names[1],scores[1]*100))
    predictions=model.predict(X_test, batch_size=128)
    predictions=np.around(predictions,0)
    accruracy=accuracy_score(Y_test,predictions)
    cnf_matrix=confusion_matrix(Y_test,predictions)

    print(accruracy,cnf_matrix)
    roc_auc_score(Y_test,predictions)'''

    
run_model(0,0.2034,64)
'''
layer1_kernel_l1_list=np.linspace(0.0,0,1)
layer2_kernel_l1_list=np.linspace(0.10,0.3,30)
batch_size_list=[32,64]

for layer1_kernel_l1 in layer1_kernel_l1_list:
    for layer2_kernel_l1 in layer2_kernel_l1_list:
        for batch_size in batch_size_list:
            print(layer1_kernel_l1,layer2_kernel_l1,batch_size)
            try:
                run_model(layer1_kernel_l1,layer2_kernel_l1,batch_size)
            except:
                pass
'''
# Out:
# Train on 194306 samples, validate on 12000 samples
# Epoch 1/100
#
#  ROC_AUC - epoch:1 - score:0.820613
#
#  - 9s - loss: 11.6595 - acc: 0.7144 - val_loss: 1.7911 - val_acc: 0.8284
# Epoch 2/100
#
#  ROC_AUC - epoch:2 - score:0.830625
#
#  - 8s - loss: 1.8419 - acc: 0.7670 - val_loss: 1.7155 - val_acc: 0.8427
# Epoch 3/100
#
#  ROC_AUC - epoch:3 - score:0.834862
#
#  - 8s - loss: 1.8116 - acc: 0.7712 - val_loss: 1.7746 - val_acc: 0.7933
# Epoch 4/100
#
#  ROC_AUC - epoch:4 - score:0.837362
#
#  - 8s - loss: 1.7987 - acc: 0.7743 - val_loss: 1.7051 - val_acc: 0.8313
# Epoch 5/100
#
#  ROC_AUC - epoch:5 - score:0.839092
#
#  - 9s - loss: 1.7942 - acc: 0.7762 - val_loss: 1.7198 - val_acc: 0.8208
# Epoch 6/100
#
#  ROC_AUC - epoch:6 - score:0.840700
#
#  - 8s - loss: 1.7910 - acc: 0.7777 - val_loss: 1.8026 - val_acc: 0.7609
# Epoch 7/100
#
#  ROC_AUC - epoch:7 - score:0.841223
#
#  - 8s - loss: 1.7879 - acc: 0.7796 - val_loss: 1.7338 - val_acc: 0.8115
# Epoch 8/100
#
#  ROC_AUC - epoch:8 - score:0.841908
#
#  - 8s - loss: 1.7863 - acc: 0.7807 - val_loss: 1.6719 - val_acc: 0.8552
# Epoch 9/100
#
#  ROC_AUC - epoch:9 - score:0.842329
#
#  - 8s - loss: 1.7850 - acc: 0.7806 - val_loss: 1.8742 - val_acc: 0.7212
# Epoch 10/100
#
#  ROC_AUC - epoch:10 - score:0.841578
#
#  - 8s - loss: 1.7822 - acc: 0.7813 - val_loss: 1.7852 - val_acc: 0.7754
# Epoch 11/100
#
#  ROC_AUC - epoch:11 - score:0.842273
#
#  - 8s - loss: 1.7812 - acc: 0.7818 - val_loss: 1.8324 - val_acc: 0.7418
# Epoch 12/100
#
#  ROC_AUC - epoch:12 - score:0.841776
#
#  - 8s - loss: 1.7797 - acc: 0.7816 - val_loss: 1.7062 - val_acc: 0.8292
# Epoch 13/100
#
#  ROC_AUC - epoch:13 - score:0.842788
#
#  - 8s - loss: 1.7786 - acc: 0.7827 - val_loss: 1.7767 - val_acc: 0.7785
# Epoch 14/100
#
#  ROC_AUC - epoch:14 - score:0.843856
#
#  - 8s - loss: 1.7780 - acc: 0.7828 - val_loss: 1.8438 - val_acc: 0.7375
# Epoch 15/100
#
#  ROC_AUC - epoch:15 - score:0.843949
#
#  - 8s - loss: 1.7765 - acc: 0.7833 - val_loss: 1.8675 - val_acc: 0.7221
# Epoch 16/100
#
#  ROC_AUC - epoch:16 - score:0.842505
#
#  - 8s - loss: 1.7758 - acc: 0.7836 - val_loss: 1.8716 - val_acc: 0.7148
# Epoch 17/100
#
#  ROC_AUC - epoch:17 - score:0.845130
#
#  - 8s - loss: 1.7761 - acc: 0.7836 - val_loss: 1.7309 - val_acc: 0.8089
# Epoch 18/100
#
#  ROC_AUC - epoch:18 - score:0.843316
#
#  - 8s - loss: 1.7747 - acc: 0.7837 - val_loss: 1.8273 - val_acc: 0.7442
# Epoch 19/100
#
#  ROC_AUC - epoch:19 - score:0.844847
#
#  - 8s - loss: 1.7742 - acc: 0.7839 - val_loss: 1.7678 - val_acc: 0.7843
# Epoch 20/100
#
#  ROC_AUC - epoch:20 - score:0.845498
#
#  - 8s - loss: 1.7735 - acc: 0.7849 - val_loss: 1.7490 - val_acc: 0.8074
# Epoch 21/100
#
#  ROC_AUC - epoch:21 - score:0.843244
#
#  - 8s - loss: 1.7732 - acc: 0.7842 - val_loss: 1.7877 - val_acc: 0.7675
# Epoch 22/100
#
#  ROC_AUC - epoch:22 - score:0.845608
#
#  - 8s - loss: 1.7725 - acc: 0.7846 - val_loss: 1.8628 - val_acc: 0.7282
# Epoch 23/100
#
#  ROC_AUC - epoch:23 - score:0.843028
#
#  - 8s - loss: 1.7717 - acc: 0.7856 - val_loss: 1.8071 - val_acc: 0.7533
# Epoch 24/100
#
#  ROC_AUC - epoch:24 - score:0.841721
#
#  - 8s - loss: 1.7710 - acc: 0.7853 - val_loss: 1.8276 - val_acc: 0.7437
# Epoch 25/100
#
#  ROC_AUC - epoch:25 - score:0.845662
#
#  - 9s - loss: 1.7715 - acc: 0.7860 - val_loss: 1.8925 - val_acc: 0.7131
# Epoch 26/100
#
#  ROC_AUC - epoch:26 - score:0.844206
#
#  - 8s - loss: 1.7701 - acc: 0.7865 - val_loss: 1.7345 - val_acc: 0.8001
# Epoch 27/100
#
#  ROC_AUC - epoch:27 - score:0.844940
#
#  - 8s - loss: 1.7700 - acc: 0.7857 - val_loss: 1.8030 - val_acc: 0.7623
# Epoch 28/100
#
#  ROC_AUC - epoch:28 - score:0.843548
#
#  - 8s - loss: 1.7696 - acc: 0.7865 - val_loss: 1.7864 - val_acc: 0.7671
# Epoch 29/100
#
#  ROC_AUC - epoch:29 - score:0.844886
#
#  - 8s - loss: 1.7690 - acc: 0.7864 - val_loss: 1.7696 - val_acc: 0.7805
# Epoch 30/100
#
#  ROC_AUC - epoch:30 - score:0.842929
#
#  - 8s - loss: 1.7694 - acc: 0.7861 - val_loss: 1.8458 - val_acc: 0.7278

# %% [markdown]
# # 对偏差数据再次训练

# %%
model = load_model('模型/dnn/auc0.8511444998782415,0.0,0.20344827586206896,64.h5')
y=model.predict(X_train)
last_pre=pd.DataFrame(y)
roc_auc_score(Y_train,last_pre)
# Out:
# 0.871766473732097

# %%
a1=0.3
a2=0.7
x_train=pd.DataFrame(X_train)
y_train=pd.DataFrame(Y_train)
x_train=x_train.loc[(last_pre.iloc[:,0]<a1)|(last_pre.iloc[:,0]>a2)]
print(len(x_train)/len(X_train))
y_values=model.predict(x_train.values)
predictions=pd.DataFrame(y_values)
roc_auc_score(y_train.loc[(last_pre.iloc[:,0]<a1)|(last_pre.iloc[:,0]>a2)],predictions)
# Out:
# 0.6930974854096117
# 0.9150976033528757

# %%
y_train.loc[(last_pre.iloc[:,0]<0.3)|(last_pre.iloc[:,0]>0.7)]
# Out:
#         0
# 0       0
# 1       0
# 2       0
# 5       0
# 6       0
# 7       0
# 11      0
# 12      0
# 13      0
# 16      0
# 17      0
# 18      0
# 20      0
# 24      0
# 25      0
# 26      0
# 27      0
# 29      0
# 31      0
# 32      1
# 33      0
# 34      1
# 35      0
# 36      1
# 37      1
# 38      0
# 39      1
# 41      0
# 42      0
# 43      0
# ...    ..
# 194267  1
# 194268  1
# 194269  1
# 194272  1
# 194273  1
# 194274  1
# 194275  1
# 194276  1
# 194278  1
# 194279  1
# 194280  1
# 194281  1
# 194282  1
# 194283  1
# 194284  1
# 194286  1
# 194288  1
# 194289  1
# 194290  1
# 194291  1
# 194292  1
# 194293  1
# 194294  1
# 194296  1
# 194297  1
# 194298  1
# 194299  1
# 194301  1
# 194302  1
# 194303  1
#
# [134673 rows x 1 columns]

# %% [markdown]
# # 结果预测

# %%
dataset = pd.read_csv("Dataset/blueTestData/ANTIF_PREDICT_SET.csv",header=0,index_col=0)
model = load_model('模型/dnn/auc0.8511444998782415,0.0,0.20344827586206896,64.h5')
X=dataset
y=np.around(model.predict(X),0)
y=model.predict(X)
y_df=pd.DataFrame(y)
y_df.index=dataset.index
y_df.to_csv('Dataset/blueTestData/ANTIF_FH_SX_04_20190922_03.csv')
# Out:
# WARNING:tensorflow:From d:\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From d:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
dataset_test = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡)线下测试集.csv",header=0,index_col=0)
model = load_model('模型/dnn/auc0.7706559727162928,0.0,0.2,64.h5')
X_test=dataset_test.drop(columns =['target']).values
Y_test=dataset_test['target'].values
X=X_test
#predictions=np.around(model.predict(X),0)
predictions=model.predict(X)
#accruracy=accuracy_score(Y_test,predictions)
#cnf_matrix=confusion_matrix(Y_test,predictions)

#print(accruracy,cnf_matrix)
roc_auc_score(Y_test,predictions)
# Out:
# 0.8431257961724982
