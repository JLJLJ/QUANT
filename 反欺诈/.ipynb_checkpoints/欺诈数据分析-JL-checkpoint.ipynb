# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

import matplotlib as mpl
import seaborn as sns

import time
from functools import wraps
#import pysnooper


def fn_timer(function):
  @wraps(function)
  def function_timer(*args, **kwargs):
    t0 = time.time()
    result = function(*args, **kwargs)
    t1 = time.time()
    print ("Total time running %s: %s seconds" %
        (function.__name__, str(t1-t0)))
    return result
  return function_timer

# %matplotlib inline

dataset_train = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡).csv",header=0,index_col=0)
X_train=dataset_train.drop(columns =['target']).values
Y_train=dataset_train['target'].values

dataset_test = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡)线下测试集.csv",header=0,index_col=0)
X_test=dataset_test.drop(columns =['target']).values
Y_test=dataset_test['target'].values

# %%
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score  
from xgboost import XGBClassifier
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.wrappers import scikit_learn

import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

def run_model(layer1_kernel_l1,layer1_kernel_l2,layer2_kernel_l1,layer2_kernel_l2,batch_size):
    class RocAucEvaluation(Callback):
        def __init__(self, validation_data=(), interval=1):
            super(Callback, self).__init__()
            self.interval = interval
            self.x_val,self.y_val = validation_data
        def on_epoch_end(self, epoch, log={}):
            if epoch % self.interval == 0:
                #y_pred = self.model.predict(self.x_val, verbose=0)
                y_pred = np.around(self.model.predict(self.x_val, verbose=0),0)
                score = roc_auc_score(self.y_val, y_pred)
                if(score>0.7661):
                    model.save('模型/dnn/auc'+str(score)+'.h5')
                    print('模型已保存:'+'模型/dnn/auc'+str(score)+'.h5')
                print('\n ROC_AUC - epoch:%d - score:%.6f \n' % (epoch+1, score))

    RocAuc = RocAucEvaluation(validation_data=(X_test, Y_test), interval=1)
    
    model = Sequential()
    model.add(Dense(units=128, activation='relu', input_dim=200,
                    #kernel_regularizer=regularizers.l2(0.01),
                    #activity_regularizer=regularizers.l1(0.01) #效果挺好
                   kernel_regularizer=regularizers.l1(0.05)

                   ))
    model.add(Dense(units=128,activation='relu',
                   kernel_regularizer=regularizers.l2(0.15)

                   ))
    model.add(Dense(units=64,activation='relu'))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    #model.compile(loss='binary_crossentropy',optimizer='adam',metrics=[roc_auc_score])
    #model.fit(X_train,Y_train,epochs=500,batch_size=128)
    model.fit(X_train, Y_train, batch_size=512, epochs=100, validation_data=(X_test, Y_test), callbacks=[RocAuc], verbose=2)

    #evaluate the model
    scores = model.evaluate(X_test,Y_test)
    print("\n%s:%.2f%%" % (model.metrics_names[1],scores[1]*100))
    predictions=model.predict(X_test, batch_size=128)
    predictions=np.around(predictions,0)
    accruracy=accuracy_score(Y_test,predictions)
    cnf_matrix=confusion_matrix(Y_test,predictions)

    print(accruracy,cnf_matrix)
    roc_auc_score(Y_test,predictions)

layer1_kernel_l1_list=np.linspace(0,0.5,5)
layer1_kernel_l2_list=np.linspace(0,0.5,5)
layer2_kernel_l1_list=np.linspace(0,0.5,5)
layer2_kernel_l2_list=np.linspace(0,0.5,5)
batch_size_list=[8,16,64,128,512,1024]


while(True):
    for()
# Out:
# Train on 194306 samples, validate on 12000 samples
# Epoch 1/100
#
#  ROC_AUC - epoch:1 - score:0.500000
#
#  - 2s - loss: 5.7745 - acc: 0.5019 - val_loss: 2.0512 - val_acc: 0.1010
# Epoch 2/100
#
#  ROC_AUC - epoch:2 - score:0.500000
#
#  - 2s - loss: 2.0483 - acc: 0.4999 - val_loss: 2.0580 - val_acc: 0.1010
# Epoch 3/100
#
#  ROC_AUC - epoch:3 - score:0.500000
#
#  - 2s - loss: 2.0568 - acc: 0.4999 - val_loss: 2.0538 - val_acc: 0.8990
# Epoch 4/100
#
#  ROC_AUC - epoch:4 - score:0.500000
#
#  - 2s - loss: 2.0607 - acc: 0.4996 - val_loss: 2.0614 - val_acc: 0.8990
# Epoch 5/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-de1974c72b74> in <module>
#      57 #model.compile(loss='binary_crossentropy',optimizer='adam',metrics=[roc_auc_score])
#      58 #model.fit(X_train,Y_train,epochs=500,batch_size=128)
# ---> 59 model.fit(X_train, Y_train, batch_size=512, epochs=100, validation_data=(X_test, Y_test), callbacks=[RocAuc], verbose=2)
#      60
#      61 #evaluate the model
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, max_queue_size, workers, use_multiprocessing, **kwargs)
#     878           initial_epoch=initial_epoch,
#     879           steps_per_epoch=steps_per_epoch,
# --> 880           validation_steps=validation_steps)
#     881
#     882   def evaluate(self,
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, mode, validation_in_fit, **kwargs)
#     368           training_utils.make_logs(model, val_results, mode, prefix='val_'))
#     369
# --> 370     callbacks.on_epoch_end(epoch, epoch_logs, mode=mode)
#     371     progbar.on_epoch_end(epoch, epoch_logs)
#     372   callbacks._call_end_hook(mode)
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs, mode)
#     249       logs = logs or {}
#     250       for callback in self.callbacks:
# --> 251         callback.on_epoch_end(epoch, logs)
#     252
#     253   def on_train_batch_begin(self, batch, logs=None):
#
# <ipython-input-11-de1974c72b74> in on_epoch_end(self, epoch, log)
#      30         if epoch % self.interval == 0:
#      31             #y_pred = self.model.predict(self.x_val, verbose=0)
# ---> 32             y_pred = np.around(self.model.predict(self.x_val, verbose=0),0)
#      33             score = roc_auc_score(self.y_val, y_pred)
#      34             if(score>0.7661):
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, max_queue_size, workers, use_multiprocessing)
#    1111     else:
#    1112       return training_arrays.predict_loop(
# -> 1113           self, x, batch_size=batch_size, verbose=verbose, steps=steps)
#    1114
#    1115   def reset_metrics(self):
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, mode, validation_in_fit, **kwargs)
#     310             ins_batch = slice_arrays(ins[:-1], batch_ids) + [ins[-1]]
#     311           else:
# --> 312             ins_batch = slice_arrays(ins, batch_ids)
#     313         except TypeError:
#     314           raise TypeError('TypeError while preparing batch. '
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py in slice_arrays(arrays, start, stop)
#     524       if hasattr(start, 'shape'):
#     525         start = start.tolist()
# --> 526       return [None if x is None else x[start] for x in arrays]
#     527     else:
#     528       return [None if x is None else x[start:stop] for x in arrays]
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py in <listcomp>(.0)
#     524       if hasattr(start, 'shape'):
#     525         start = start.tolist()
# --> 526       return [None if x is None else x[start] for x in arrays]
#     527     else:
#     528       return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
dataset = pd.read_csv("Dataset/blueTestData/ANTIF_PREDICT_SET.csv",header=0,index_col=0)
model = load_model('模型/dnn/auc0.7661005811370905.h5')
X=dataset
y=np.around(model.predict(X),0)
y=model.predict(X)
y_df=pd.DataFrame(y)
y_df.index=dataset.index
y_df.to_csv('Dataset/blueTestData/ANTIF_FH_SX_04_20190921_02.csv')

# %%
dataset_test = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡)线下测试集.csv",header=0,index_col=0)
model = load_model('模型/dnn/auc0.7706559727162928,0.0,0.2,64.h5')
X_test=dataset_test.drop(columns =['target']).values
Y_test=dataset_test['target'].values
X=X_test
#predictions=np.around(model.predict(X),0)
predictions=model.predict(X)
accruracy=accuracy_score(Y_test,predictions)
#cnf_matrix=confusion_matrix(Y_test,predictions)

#print(accruracy,cnf_matrix)
roc_auc_score(Y_test,predictions)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# InternalError: GPU sync failed
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-5-84724feceb38> in <module>
#       1 dataset_test = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(平衡)线下测试集.csv",header=0,index_col=0)
# ----> 2 model = load_model('模型/dnn/auc0.7706559727162928,0.0,0.2,64.h5')
#       3 X_test=dataset_test.drop(columns =['target']).values
#       4 Y_test=dataset_test['target'].values
#       5 X=X_test
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     235
#     236     # set weights
# --> 237     load_weights_from_hdf5_group(f['model_weights'], model.layers)
#     238
#     239     if compile:
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\saving.py in load_weights_from_hdf5_group(f, layers)
#     818                        str(len(weight_values)) + ' elements.')
#     819     weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 820   K.batch_set_value(weight_value_tuples)
#     821
#     822
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in batch_set_value(tuples)
#    2878           assign_ops.append(assign_op)
#    2879           feed_dict[assign_placeholder] = value
# -> 2880         get_session().run(assign_ops, feed_dict=feed_dict)
#    2881
#    2882
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in get_session()
#     480   if not _MANUAL_VAR_INIT:
#     481     with session.graph.as_default():
# --> 482       _initialize_variables(session)
#     483   return session
#     484
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in _initialize_variables(session)
#     756     # marked as initialized.
#     757     is_initialized = session.run(
# --> 758         [variables_module.is_variable_initialized(v) for v in candidate_vars])
#     759     uninitialized_vars = []
#     760     for flag, v in zip(is_initialized, candidate_vars):
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# d:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# InternalError: GPU sync failed

# %%
from sklearn.metrics import roc_auc_score
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score  
from xgboost import XGBClassifier
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.model_selection import GridSearchCV
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.wrappers import scikit_learn
