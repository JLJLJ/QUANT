# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

import matplotlib as mpl
import seaborn as sns

import time
from functools import wraps

import pysnooper


def fn_timer(function):
  @wraps(function)
  def function_timer(*args, **kwargs):
    t0 = time.time()
    result = function(*args, **kwargs)
    t1 = time.time()
    print ("Total time running %s: %s seconds" %
        (function.__name__, str(t1-t0)))
    return result
  return function_timer

# %matplotlib inline
dataset = pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET.csv",header=0,index_col=0)
dataset_x=dataset.drop(['target'],axis=1)
dataset_y=dataset['target']
X_train,X_test,Y_train,Y_test=train_test_split(dataset_x,dataset_y,test_size=0.1,random_state=0)

@fn_timer
def balance(x,y):
    x=x.copy()
    y=y.copy()
    columns=x.columns
    sm=SMOTE(random_state=0)
    X,Y=sm.fit_sample(x,y)
    X=pd.DataFrame(X)
    X.columns=columns
    Y=pd.Series(Y)
    Y.name='target'
    return X,Y

'''def split_list(x,y):
    for i in range(len(x.columns)):
        x.iloc[:,i]=pd.cut(x.iloc[:,i],5,retbins=False)
    return x,y'''
@fn_timer
def convert2one_hot(x,y):
    x=x.copy()
    y=y.copy()
    x=pd.get_dummies(x)
    return x,y

# %%
import woe.feature_process as fp
import woe.eval as eval
@fn_timer
def split_list(x,y,path='分箱.csv',isread=False,min_sample=0.1,alpha=0.01):
    #%% woe分箱, iv and transform
    x=x.copy()
    if(isread==False):
        splited_list=pd.DataFrame([],columns=['split_list','feature_name'])
        data=x.copy() #用于存储所有数据的woe值
        data['target']=y
        data_woe=data
        civ_list = []
        n_positive = sum(y)
        n_negtive = len(y) - n_positive
        min_sample=min_sample*len(data)
        alpha=0.01  #用于自动计算分箱时的一个标准，默认0.01.如果iv_划分>iv_不划分*（1+alpha)则划分。
        for column in x.columns:
            if x[column].dtypes == 'object':
                #如果这列是标签列，则使用proc_woe_discrete
                civ = fp.proc_woe_discrete(data, column, n_positive, n_negtive, min_sample, alpha=alpha)
            else:     
                #如果这列是连续变量，则使用proc_woe_continuous
                civ = fp.proc_woe_continuous(data, column, n_positive, n_negtive, min_sample, alpha=alpha)
            df=pd.DataFrame([float('-inf')]+civ.split_list+[float('inf')],columns=['split_list'])
            df['feature_name']=column
            splited_list=pd.concat([splited_list,df],axis=0)
            x[column]=pd.cut(x[column],[float('-inf')]+civ.split_list+[float('inf')])

        if(path!=''):
            splited_list.to_csv(path)
    else:
        splited_list=pd.read_csv(path,header=0,index_col=0)
        for column in x.columns:
            x[column]=pd.cut(x[column],splited_list[splited_list['feature_name']==column]['split_list'])
        
    
    '''civ_list.append(civ)
        data_woe[column] = fp.woe_trans(data[column], civ)

    civ_df = eval.eval_feature_detail(civ_list,'woe特征分箱.csv')
    #删除iv值过小的变量
    iv_thre = 0.001
    iv = civ_df[['var_name','split_list','iv']].drop_duplicates()
    x_columns = iv[iv.iv > iv_thre]'''
    
    return x,y,splited_list

# %% [markdown]
# # 训练数据保存

# %%
X_train,Y_train=balance(X_train,Y_train)
X_train,Y_train,splited_list=split_list(X_train,Y_train,'分桶/woe分桶.csv',False)
X_train,Y_train=convert2one_hot(X_train,Y_train)
print(X_train.shape)

X_test,Y_test,temp=split_list(X_test,Y_test,'分桶/woe分桶.csv',True)
X_test,Y_test=convert2one_hot(X_test,Y_test)
print(X_test.shape)

'''dataset_x,dataset_y=balance(dataset_x,dataset_y)
dataset_x,dataset_y=split_list(dataset_x,dataset_y,'分桶/woe分桶.csv',False)
dataset_x,dataset_y=convert2one_hot(dataset_x,dataset_y)
print(dataset_x.shape)

dataset_save=dataset_x
dataset_save['target']=dataset_y'''
dataset_train_save=X_train.copy()
dataset_train_save['target']=Y_train.copy()
dataset_test_save=X_test.copy()
dataset_test_save['target']=Y_test .copy()


#print(dataset_save.shape)
print(dataset_train_save.shape)
print(dataset_test_save.shape)
# Out:
# Total time running balance: 40.72253608703613 seconds
# ---------------process continuous variable:0----------------
# ---------------process continuous variable:1----------------
# ---------------process continuous variable:2----------------
# ---------------process continuous variable:3----------------
# ---------------process continuous variable:4----------------
# ---------------process continuous variable:5----------------
# ---------------process continuous variable:6----------------
# ---------------process continuous variable:7----------------
# ---------------process continuous variable:8----------------
# ---------------process continuous variable:9----------------
# ---------------process continuous variable:10---------------
# ---------------process continuous variable:11---------------
# ---------------process continuous variable:12---------------
# ---------------process continuous variable:13---------------
# ---------------process continuous variable:14---------------
# ---------------process continuous variable:15---------------
# ---------------process continuous variable:16---------------
# ---------------process continuous variable:17---------------
# ---------------process continuous variable:18---------------
# ---------------process continuous variable:19---------------
# ---------------process continuous variable:20---------------
# ---------------process continuous variable:21---------------
# ---------------process continuous variable:22---------------
# ---------------process continuous variable:23---------------
# ---------------process continuous variable:24---------------
# ---------------process continuous variable:25---------------
# ---------------process continuous variable:26---------------
# ---------------process continuous variable:27---------------
# ---------------process continuous variable:28---------------
# ---------------process continuous variable:29---------------
# ---------------process continuous variable:30---------------
# ---------------process continuous variable:31---------------
# ---------------process continuous variable:32---------------
# ---------------process continuous variable:33---------------
# ---------------process continuous variable:34---------------
# ---------------process continuous variable:35---------------
# ---------------process continuous variable:36---------------
# ---------------process continuous variable:37---------------
# ---------------process continuous variable:38---------------
# ---------------process continuous variable:39---------------
# ---------------process continuous variable:40---------------
# ---------------process continuous variable:41---------------
# ---------------process continuous variable:42---------------
# ---------------process continuous variable:43---------------
# ---------------process continuous variable:44---------------
# ---------------process continuous variable:45---------------
# ---------------process continuous variable:46---------------
# ---------------process continuous variable:47---------------
# ---------------process continuous variable:48---------------
# ---------------process continuous variable:49---------------
# ---------------process continuous variable:50---------------
# ---------------process continuous variable:51---------------
# ---------------process continuous variable:52---------------
# ---------------process continuous variable:53---------------
# ---------------process continuous variable:54---------------
# ---------------process continuous variable:55---------------
# ---------------process continuous variable:56---------------
# ---------------process continuous variable:57---------------
# ---------------process continuous variable:58---------------
# ---------------process continuous variable:59---------------
# ---------------process continuous variable:60---------------
# ---------------process continuous variable:61---------------
# ---------------process continuous variable:62---------------
# ---------------process continuous variable:63---------------
# ---------------process continuous variable:64---------------
# ---------------process continuous variable:65---------------
# ---------------process continuous variable:66---------------
# ---------------process continuous variable:67---------------
# ---------------process continuous variable:68---------------
# ---------------process continuous variable:69---------------
# ---------------process continuous variable:70---------------
# ---------------process continuous variable:71---------------
# ---------------process continuous variable:72---------------
# ---------------process continuous variable:73---------------
# ---------------process continuous variable:74---------------
# ---------------process continuous variable:75---------------
# ---------------process continuous variable:76---------------
# ---------------process continuous variable:77---------------
# ---------------process continuous variable:78---------------
# ---------------process continuous variable:79---------------
# ---------------process continuous variable:80---------------
# ---------------process continuous variable:81---------------
# ---------------process continuous variable:82---------------
# ---------------process continuous variable:83---------------
# ---------------process continuous variable:84---------------
# ---------------process continuous variable:85---------------
# ---------------process continuous variable:86---------------
# ---------------process continuous variable:87---------------
# ---------------process continuous variable:88---------------
# ---------------process continuous variable:89---------------
# ---------------process continuous variable:90---------------
# ---------------process continuous variable:91---------------
# ---------------process continuous variable:92---------------
# ---------------process continuous variable:93---------------
# ---------------process continuous variable:94---------------
# ---------------process continuous variable:95---------------
# ---------------process continuous variable:96---------------
# ---------------process continuous variable:97---------------
# ---------------process continuous variable:98---------------
# ---------------process continuous variable:99---------------
# --------------process continuous variable:100---------------
# --------------process continuous variable:101---------------
# --------------process continuous variable:102---------------
# --------------process continuous variable:103---------------
# --------------process continuous variable:104---------------
# --------------process continuous variable:105---------------
# --------------process continuous variable:106---------------
# --------------process continuous variable:107---------------
# --------------process continuous variable:108---------------
# --------------process continuous variable:109---------------
# --------------process continuous variable:110---------------
# --------------process continuous variable:111---------------
# --------------process continuous variable:112---------------
# --------------process continuous variable:113---------------
# --------------process continuous variable:114---------------
# --------------process continuous variable:115---------------
# --------------process continuous variable:116---------------
# --------------process continuous variable:117---------------
# --------------process continuous variable:118---------------
# --------------process continuous variable:119---------------
# --------------process continuous variable:120---------------
# --------------process continuous variable:121---------------
# --------------process continuous variable:122---------------
# --------------process continuous variable:123---------------
# --------------process continuous variable:124---------------
# --------------process continuous variable:125---------------
# --------------process continuous variable:126---------------
# --------------process continuous variable:127---------------
# --------------process continuous variable:128---------------
# --------------process continuous variable:129---------------
# --------------process continuous variable:130---------------
# --------------process continuous variable:131---------------
# --------------process continuous variable:132---------------
# --------------process continuous variable:133---------------
# --------------process continuous variable:134---------------
# --------------process continuous variable:135---------------
# --------------process continuous variable:136---------------
# --------------process continuous variable:137---------------
# --------------process continuous variable:138---------------
# --------------process continuous variable:139---------------
# --------------process continuous variable:140---------------
# --------------process continuous variable:141---------------
# --------------process continuous variable:142---------------
# --------------process continuous variable:143---------------
# --------------process continuous variable:144---------------
# --------------process continuous variable:145---------------
# --------------process continuous variable:146---------------
# --------------process continuous variable:147---------------
# --------------process continuous variable:148---------------
# --------------process continuous variable:149---------------
# --------------process continuous variable:150---------------
# --------------process continuous variable:151---------------
# --------------process continuous variable:152---------------
# --------------process continuous variable:153---------------
# --------------process continuous variable:154---------------
# --------------process continuous variable:155---------------
# --------------process continuous variable:156---------------
# --------------process continuous variable:157---------------
# --------------process continuous variable:158---------------
# --------------process continuous variable:159---------------
# --------------process continuous variable:160---------------
# --------------process continuous variable:161---------------
# --------------process continuous variable:162---------------
# --------------process continuous variable:163---------------
# --------------process continuous variable:164---------------
# --------------process continuous variable:165---------------
# --------------process continuous variable:166---------------
# --------------process continuous variable:167---------------
# --------------process continuous variable:168---------------
# --------------process continuous variable:169---------------
# --------------process continuous variable:170---------------
# --------------process continuous variable:171---------------
# --------------process continuous variable:172---------------
# --------------process continuous variable:173---------------
# --------------process continuous variable:174---------------
# --------------process continuous variable:175---------------
# --------------process continuous variable:176---------------
# --------------process continuous variable:177---------------
# --------------process continuous variable:178---------------
# --------------process continuous variable:179---------------
# --------------process continuous variable:180---------------
# --------------process continuous variable:181---------------
# --------------process continuous variable:182---------------
# --------------process continuous variable:183---------------
# --------------process continuous variable:184---------------
# --------------process continuous variable:185---------------
# --------------process continuous variable:186---------------
# --------------process continuous variable:187---------------
# --------------process continuous variable:188---------------
# --------------process continuous variable:189---------------
# --------------process continuous variable:190---------------
# --------------process continuous variable:191---------------
# --------------process continuous variable:192---------------
# --------------process continuous variable:193---------------
# --------------process continuous variable:194---------------
# --------------process continuous variable:195---------------
# --------------process continuous variable:196---------------
# --------------process continuous variable:197---------------
# --------------process continuous variable:198---------------
# --------------process continuous variable:199---------------
# Total time running split_list: 5656.583019733429 seconds
# Total time running convert2one_hot: 1.308608055114746 seconds
# (194306, 3663)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# d:\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Total time running split_list: 1.6605689525604248 seconds
# Total time running convert2one_hot: 0.09474635124206543 seconds
# (12000, 0)
# (194306, 3664)
# (12000, 1)

# %%
#dataset_save.to_csv("Dataset/trainData/ANTIF_TRAIN_SET_(分桶+onehot+平衡)全量.csv")
dataset_train_save.to_csv("Dataset/trainData/ANTIF_TRAIN_SET_(分桶+onehot+平衡).csv")
dataset_test_save.to_csv("Dataset/trainData/ANTIF_TRAIN_SET_(分桶+onehot+平衡)线下测试集.csv")
pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(分桶+onehot+平衡).csv",header=0,index_col=0)
# Out:
#         0_(-inf, 12.635]  0_(12.635, 14.194]  0_(14.194, 15.889]  \
# 0                      0                   0                   1
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   1                   0
# 4                      0                   0                   1
# 5                      0                   0                   0
# 6                      0                   0                   0
# 7                      0                   0                   0
# 8                      0                   0                   0
# 9                      0                   0                   0
# 10                     0                   0                   0
# 11                     1                   0                   0
# 12                     0                   0                   0
# 13                     0                   0                   0
# 14                     0                   0                   0
# 15                     0                   1                   0
# 16                     0                   0                   0
# 17                     0                   0                   0
# 18                     0                   0                   0
# 19                     0                   0                   0
# 20                     0                   0                   0
# 21                     1                   0                   0
# 22                     0                   0                   0
# 23                     0                   0                   0
# 24                     0                   0                   1
# 25                     0                   0                   1
# 26                     0                   0                   0
# 27                     0                   0                   0
# 28                     0                   0                   0
# 29                     0                   0                   1
# ...                  ...                 ...                 ...
# 194276                 0                   0                   0
# 194277                 0                   0                   0
# 194278                 0                   0                   0
# 194279                 0                   0                   0
# 194280                 0                   0                   0
# 194281                 0                   0                   0
# 194282                 0                   0                   1
# 194283                 0                   0                   0
# 194284                 0                   0                   1
# 194285                 0                   0                   0
# 194286                 0                   0                   0
# 194287                 0                   0                   0
# 194288                 0                   0                   0
# 194289                 0                   0                   0
# 194290                 0                   0                   0
# 194291                 0                   0                   0
# 194292                 0                   0                   0
# 194293                 0                   0                   0
# 194294                 0                   0                   0
# 194295                 0                   0                   0
# 194296                 0                   0                   1
# 194297                 0                   0                   0
# 194298                 0                   0                   0
# 194299                 0                   0                   0
# 194300                 0                   0                   0
# 194301                 0                   0                   0
# 194302                 0                   0                   1
# 194303                 0                   0                   0
# 194304                 0                   0                   0
# 194305                 0                   0                   1
#
#         0_(15.889, 16.497]  0_(16.497, 17.131]  0_(17.131, 18.008]  \
# 0                        0                   0                   0
# 1                        0                   0                   0
# 2                        0                   0                   0
# 3                        0                   0                   0
# 4                
# 194292                  0       1
# 194293                  0       1
# 194294                  0       1
# 194295                  0       1
# 194296                  0       1
# 194297                  0       1
# 194298                  0       1
# 194299                  0       1
# 194300                  0       1
# 194301                  0       1
# 194302                  0       1
# 194303                  0       1
# 194304                  0       1
# 194305                  0       1
#
# [194306 rows x 3664 columns]

# %%
pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(分桶+onehot+平衡)线下测试集.csv",header=0,index_col=0).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-10c6a84acbfe> in <module>
# ----> 1 pd.read_csv("Dataset/trainData/ANTIF_TRAIN_SET_(分桶+onehot+平衡)线下测试集.csv",header=0,index_col=0).shape
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 1.数据平衡

# %% [markdown]
# ## 1.1下采样

# %%
df_y0=dataset_y[dataset_y==0].iloc[0:12000]
df_y1=dataset_y[dataset_y==1]
df_x0=dataset_x[dataset_y==0].iloc[0:12000]
df_x1=dataset_x[dataset_y==1]
dataset_x=pd.concat([df_x0,df_x1],axis=0)
dataset_y=pd.concat([df_y0,df_y1],axis=0)

# %% [markdown]
# ## 1.2 SMOTE

# %%
def balance(x,y):
    sm=SMOTE(random_state=0)
    X,Y=sm.fit_sample(x,y)
    return pd.DataFrame(X),pd.Series(Y)

#X_train,Y_train=smote(X_train,Y_train)

# %% [markdown]
# # 2.分箱
# 对应的分箱方法：
# A. 无监督： (1) 等宽 (2) 等频  (3) 聚类
#
# B. 有监督 (1) 卡方分箱法(ChiMerge)  (2) ID3、C4.5、CART等单变量决策树算法  (3)  信用评分建模的IV最大化分箱 等
#
# 以下基于CART算法对连续变量进行最优分箱
#
# 由于CART是决策树分类算法，所以相当于是单变量决策树分类。
#
# 简单介绍下理论：
#
# CART是二叉树，每次仅进行二元分类，对于连续性变量，方法是依次计算相邻两元素值的中位数，将数据集一分为二，计算该点作为切割点时的基尼值较分割前的基尼值下降程度，每次切分时，选择基尼下降程度最大的点为最优切分点，再将切分后的数据集按同样原则切分，直至终止条件为止。
#
# 关于CART分类的终止条件：视实际情况而定，以下设置为 a.每个叶子节点的样本量>=总样本量的5%   b.内部节点再划分所需的最小样本数>=总样本量的10%

# %% [markdown]
# ## 2.1 CART分箱

# %%
def calc_score_median(sample_set, var):
    '''
    计算相邻评分的中位数，以便进行决策树二元切分
    param sample_set: 待切分样本
    param var: 分割变量名称
    '''
    var_list = list(np.unique(sample_set[var]))
    var_median_list = []
    for i in range(len(var_list) -1):
        var_median = (var_list[i] + var_list[i+1]) / 2
        var_median_list.append(var_median)
    return var_median_list

#var表示需要进行分箱的变量名，返回一个样本变量中位数的list
def choose_best_split(sample_set, var, min_sample):
    '''
    使用CART分类决策树选择最好的样本切分点
    返回切分点
    param sample_set: 待切分样本
    param var: 分割变量名称
    param min_sample: 待切分样本的最小样本量(限制条件)
    '''
    # 根据样本评分计算相邻不同分数的中间值
    score_median_list = calc_score_median(sample_set, var)
    median_len = len(score_median_list)
    sample_cnt = sample_set.shape[0]
    sample1_cnt = sum(sample_set['target'])
    sample0_cnt =  sample_cnt- sample1_cnt
    Gini = 1 - np.square(sample1_cnt / sample_cnt) - np.square(sample0_cnt / sample_cnt)
    
    bestGini = 0.0; bestSplit_point = 0.0; bestSplit_position = 0.0
    for i in range(median_len):
        left = sample_set[sample_set[var] < score_median_list[i]]
        right = sample_set[sample_set[var] > score_median_list[i]]
        
        left_cnt = left.shape[0]; right_cnt = right.shape[0]
        left1_cnt = sum(left['target']); right1_cnt = sum(right['target'])
        left0_cnt =  left_cnt - left1_cnt; right0_cnt =  right_cnt - right1_cnt
        left_ratio = left_cnt / sample_cnt; right_ratio = right_cnt / sample_cnt
        
        if left_cnt < min_sample or right_cnt < min_sample:
            continue
        
        Gini_left = 1 - np.square(left1_cnt / left_cnt) - np.square(left0_cnt / left_cnt)
        Gini_right = 1 - np.square(right1_cnt / right_cnt) - np.square(right0_cnt / right_cnt)
        Gini_temp = Gini - (left_ratio * Gini_left + right_ratio * Gini_right)
        if Gini_temp > bestGini:
            bestGini = Gini_temp; bestSplit_point = score_median_list[i]
            if median_len > 1:
                bestSplit_position = i / (median_len - 1)
            else:
                bestSplit_position = i / median_len
        else:
            continue
               
    Gini = Gini - bestGini
    return bestSplit_point, bestSplit_position

#min_sample 参数为最小叶子节点的样本阈值，如果小于该阈值则不进行切分，如前面所述设置为整体样本量的5%
#返回的结果我这里只返回了最优分割点，如果需要返回其他的比如GINI值，可以自行添加。
def bining_data_split(sample_set, var, min_sample, split_list):
    '''
    划分数据找到最优分割点list
    param sample_set: 待切分样本
    param var: 分割变量名称
    param min_sample: 待切分样本的最小样本量(限制条件)
    param split_list: 最优分割点list
    '''
    split, position = choose_best_split(sample_set, var, min_sample)
    if split != 0.0:
        split_list.append(split)
    # 根据分割点划分数据集，继续进行划分
    sample_set_left = sample_set[sample_set[var] < split]
    sample_set_right = sample_set[sample_set[var] > split]
    # 如果左子树样本量超过2倍最小样本量，且分割点不是第一个分割点，则切分左子树
    if len(sample_set_left) >= min_sample * 2 and position not in [0.0, 1.0]:
        bining_data_split(sample_set_left, var, min_sample, split_list)
    else:
        None
    # 如果右子树样本量超过2倍最小样本量，且分割点不是最后一个分割点，则切分右子树
    if len(sample_set_right) >= min_sample * 2 and position not in [0.0, 1.0]:
        bining_data_split(sample_set_right, var, min_sample, split_list)
    else:
        None
        
#split_list 参数是用来保存返回的切分点，每次切分后返回的切分点存入该list
#在这里判断切分点分割的左子树和右子树是否满足“内部节点再划分所需的最小样本数>=总样本量的10%”的条件，
#如果满足则进行递归调用。
@fn_timer
def get_bestsplit_list(sample_set, var):
    '''
    根据分箱得到最优分割点list
    param sample_set: 待切分样本
    param var: 分割变量名称
    '''
    # 计算最小样本阈值（终止条件）
    min_df = sample_set.shape[0] * 0.05
    split_list = []
    # 计算第一个和最后一个分割点
    bining_data_split(sample_set, var, min_df, split_list)
    return split_list


split_list=get_bestsplit_list(dataset,['attr_0'])
split_list

# %% [markdown]
# ## 2.2 等宽分箱
# https://www.cnblogs.com/sench/p/10128216.html

# %%
def split_list(x,y):
    for i in range(len(x.columns)):
        x.iloc[:,i]=pd.cut(x.iloc[:,i],5,retbins=False)
    return x,y
#X_train,Y_train=split_list(X_train,Y_train)

# %% [markdown]
# # 3.one-hot

# %%
def convert2one_hot(x,y):
    x=pd.get_dummies(x)
    return x,y
#X_train,Y_train=convert2one_hot(X_train,Y_train)
