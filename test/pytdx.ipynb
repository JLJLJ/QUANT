# %%
#### from pytdx.hq import TdxHq_API
import pytdx
from pytdx.hq import TDXParams
api = TdxHq_API()
if api.connect('119.147.212.81', 7709):
    # ... same codes...
    print(api.get_security_count(0))
    #data = api.to_df(api.get_history_minute_time_data(pytdx.hq.TDXParams.MARKET_SH, '000001',20150105))
    data = api.to_df(api.get_security_bars(8,0, '000001',0,250))
    print(data)
    api.disconnect()
# Out:
# 10084
#       open  close   high    low           vol        amount  year  month  day  \
# 0    14.02  13.99  14.02  13.99  9.648000e+05  1.351587e+07  2020      2    3
# 1    14.00  14.05  14.10  14.00  1.234500e+06  1.736590e+07  2020      2    3
# 2    14.05  13.99  14.05  13.99  1.698100e+06  2.381294e+07  2020      2    3
# 3    13.99  13.99  13.99  13.99  3.864000e+05  5.405736e+06  2020      2    3
# 4    13.99  13.99  13.99  13.99  2.617000e+05  3.661183e+06  2020      2    3
# 5    13.99  13.99  13.99  13.99  5.712000e+05  7.991088e+06  2020      2    3
# 6    13.99  13.99  13.99  13.99  1.171800e+06  1.639348e+07  2020      2    3
# 7    13.99  13.99  13.99  13.99  2.030000e+04  2.839970e+05  2020      2    3
# 8    13.99  13.99  13.99  13.99  5.877472e-39  5.877472e-39  2020      2    3
# 9    13.99  13.99  13.99  13.99  1.318000e+06  1.843882e+07  2020      2    3
# 10   14.05  14.17  14.23  14.05  6.524000e+06  9.227926e+07  2020      2    4
# ...

# %%
if api.connect('119.147.212.81', 7709):
    # ... same codes...
    print(api.get_security_count(0))
    data = api.to_df(api.get_transaction_data(TDXParams.MARKET_SZ, '000001', 0, 3000))
    print(data)
    api.disconnect()
# Out:
# 10084
#        time  price   vol  num  buyorsell
# 0     13:17  14.25   111   14          0
# 1     13:17  14.23   742   33          1
# 2     13:17  14.24   223   11          0
# 3     13:17  14.25   160   15          0
# 4     13:17  14.24    62    6          2
# 5     13:17  14.24   111   19          0
# 6     13:17  14.23    27    6          2
# 7     13:17  14.23   284   14          0
# 8     13:17  14.24    64    4          0
# 9     13:17  14.23   184   14          1
# 10    13:17  14.24   574   16          0
# 11    13:17  14.22   131   13          1
# 12    13:17  14.21  1021   41          1
# 13    13:17  14.20   452   25          1
# 14    13:17  14.21   558   15          0
# 15    13:17  14.23   130    8          0
# 16    13:17  14.24    92   12          0
# 17    13:17  14.23   404   12          0
# 18    13:17  14.20   952   43          1
# 19    13:18  14.25   155    7          0
# 20    13:18  14.24    59    9          1
# 21    13:18  14.22   169   17          1
# ...

# %%
if api.connect('119.147.212.81', 7709):
    # ... same codes...
    print(api.get_security_count(0))
    data = api.to_df(api.get_history_transaction_data(TDXParams.MARKET_SZ,'000001', 0, 10000, 20170209))
    print(data)
    api.disconnect()
# Out:
# 10084
#        time  price   vol  buyorsell
# 0     10:51   9.32    10          0
# 1     10:51   9.32    77          0
# 2     10:51   9.32   114          0
# 3     10:51   9.32   230          0
# 4     10:51   9.31    45          1
# 5     10:51   9.31    50          1
# 6     10:51   9.32    21          0
# 7     10:52   9.31     6          1
# 8     10:52   9.32   121          0
# 9     10:52   9.32    14          0
# 10    10:52   9.31     9          1
# 11    10:52   9.31   235          1
# 12    10:52   9.32     8          0
# 13    10:52   9.32     6          0
# 14    10:52   9.32     1          0
# 15    10:52   9.31    51          1
# 16    10:52   9.31    67          1
# 17    10:52   9.31    50          1
# 18    10:53   9.31     2          1
# 19    10:53   9.32     7          0
# 20    10:53   9.31     2          1
# 21    10:53   9.32    22          0
# 22    10:53   9.32    18          0
# 23    10:53   9.32     4          0
# 24    10:53   9.31    30          1
# ...

# %%
data = api.to_df(api.get_security_bars(9, 0, '000001', 0, 100))

# %%
data
# Out:
#   value
# 0  None
